# %%
import pandas as pd
import nltk

# %%
main_data = pd.read_csv("../../amazon_reviews_us_Grocery_v1_00.tsv",sep='\t',quoting=3)

# %%
main_data.head()
# Out:
#   marketplace  customer_id       review_id  product_id  product_parent  \
# 0          US     42521656  R26MV8D0KG6QI6  B000SAQCWC       159713740
# 1          US     12049833  R1OF8GP57AQ1A0  B00509LVIQ       138680402
# 2          US       107642  R3VDC1QB6MC4ZZ  B00KHXESLC       252021703
# 3          US      6042304  R12FA3DCF8F9ER  B000F8JIIC       752728342
# 4          US     18123821   RTWHVNV6X4CNJ  B004ZWR9RQ       552138758
#
#                                        product_title product_category  \
# 0  The Cravings Place Chocolate Chunk Cookie Mix,...          Grocery
# 1            Mauna Loa Macadamias, 11 Ounce Packages          Grocery
# 2  Organic Matcha Green Tea Powder - 100% Pure Ma...          Grocery
# 3  15oz Raspberry Lyons Designer Dessert Syrup Sauce          Grocery
# 4  Stride Spark Kinetic Fruit Sugar Free Gum, 14-...          Grocery
#
#    star_rating  helpful_votes  total_votes vine verified_purchase  \
# ...

# %%
main_data.columns
# Out:
# Index(['marketplace', 'customer_id', 'review_id', 'product_id',
#        'product_parent', 'product_title', 'product_category', 'star_rating',
#        'helpful_votes', 'total_votes', 'vine', 'verified_purchase',
#        'review_headline', 'review_body', 'review_date'],
#       dtype='object')

# %%
main_data.shape
# Out:
# (2402458, 15)

# %%
main_data['product_title'].unique().size
# Out:
# 273649

# %%
# looking for coffee filters or anything similar
main_data.query('product_title.str.contains(" filter")', engine='python')
# Out:
#         marketplace  customer_id       review_id  product_id  product_parent  \
# 20793            US     39352040  R1JIFR2VHC1F0P  B000ELGPAO       381192723
# 131134           US     39861519   RD25EZFPZ7T47  B000ELGPAO       381192723
# 153346           US     16974075  R1Q6UELQ9EVF8D  B00D1FF9TS       492750668
# 160860           US      2002790   RXWXGSMF34Q28  B00CF59TLE        55134316
# 184667           US      2354171  R2EP1TSGB72SEB  B000ELGPAO       381192723
# ...             ...          ...             ...         ...             ...
# 2391519          US     26327669   RF3IN5BPFSMQG  B0001N7QMG       230709468
# 2395185          US     44630533  R3T6TD7PB94PNY  B000ELGPAO       381192723
# 2397419          US     10661938  R38EV6I2OIZPNN  B0001N7QMG       230709468
# 2398320          US     50111582  R2GJ2YIRVIDVH7  B0001N7QMG       230709468
# 2401701          US     51076657  R2C6JBLEAIKE6F  B0000C69FP       481045724
#
# ...

# %%
# reviews only written by vine reviewers
vine_data = main_data.query('vine.str.contains("Y")', engine='python')
vine_data
# Out:
#         marketplace  customer_id       review_id  product_id  product_parent  \
# 302              US     21028674   R74RZQRH3MKUW  B00P5WYVCG         3643863
# 559              US     12100376  R37HYU6L7KWNSR  B00P5WYVCG         3643863
# 1332             US     20789642  R10ZYDTCBALOLE  B0105E0TEM       425101162
# 1455             US     40791829  R2SG1ZRKMJIMBE  B00UJOG8YO       621679997
# 1493             US     50804046  R1R0XMH6L7GZ2N  B00XSFNXJE       929245098
# ...             ...          ...             ...         ...             ...
# 2359961          US     28714491  R2OFDRDYEH3NYS  B00119OL8G       588951867
# 2359995          US     27992471  R27IQIABBO4O70  B00119OL8G       588951867
# 2360020          US     27987983   RA8YZHGBK1D1U  B00119OL8G       588951867
# 2360038          US     51729767  R17403GKN29X5S  B00119OL8G       588951867
# 2360050          US     49479912  R2S0BO6LXY03ME  B00119OL8G       588951867
#
# ...

# %%
# vine reviews that made people 'ill'?
vine_data.query('review_body.str.contains(" ill")', engine='python')
# Out:
#         marketplace  customer_id       review_id  product_id  product_parent  \
# 45798            US     50079351  R1UD05HUC9UAE8  B00W5IYX0S       803643874
# 314338           US     20101408  R26PP5JVKTD0C1  B0032GQMWO       834811358
# 340473           US     52956536  R2O7G7TFYAMHC7  B00UW29KQQ       980054659
# 348543           US     37949545   R7F0O88EX5BMH  B00TEZMCGW       579774954
# 378715           US     51391300   RT9X7KFY2I3IX  B00U3WX0HA       249331152
# 398579           US     52943698  R16ZLGNA5SP9U1  B00F9WOJYM       267238085
# 457422           US     13814078  R1EZ4XUF13KXS7  B00S79RMPC       579233707
# 477690           US     40581989  R2NZ9B9EEJVY93  B00S5M2PEY        34154549
# 677549           US     49469918  R13ATAFCJEUZQ5  B00JKM9HN0       472248565
# 743840           US     20594005   R4TWQSA94GSY0  B00LWUP3QI       959066090
# 764708           US     27600554   RNG8WYX2NADR8  B00LWUP3QI       959066090
# ...

# %%
# example vine review
vine_data.loc[1286033,'review_body']
# Out:
# "I don't use this often, but when I do I like to dip apple slices (granny smith) or ritz crackers into this spread. Almost anything goes with it, and it doesn't taste overly sweet. I'm normally not a fan of Hershey's but once in a while I will indulge in this almond spread. It's tasty and when I find myself without any proper chocolate in the house, I usually reach for this container. Not the healthiest of options out there, but you really can't eat that much all at once or you will start feeling ill. My four year old loves dipping things into this too. I would certainly buy more, but this little container actually lasts quite a while if used sparingly."

# %%
# reviews that have videos in them
main_data.query('review_body.str.contains("VIDEOID", na=False) & star_rating == 1', engine='python')
# Out:
#         marketplace  customer_id       review_id  product_id  product_parent  \
# 193422           US     19643247  R205ULU2UJZMR1  B009UT7PMS       218726047
# 396010           US     44854993   RRA4L5XLI94PX  B000UVW46W        79993318
# 610824           US     52832096   RNYDVKFC12QAQ  B0026SQZD0       561357744
# 839590           US     42381675  R34F9CBC2IFJEG  B0013E21V8       137651929
# 873815           US     51738595  R15SYWQO1B36D2  B00EAZNO72       673666080
# 890660           US     52940536  R1TZE4FAPTBMTV  B005HG9ET0       192623861
# 955137           US     46134554  R10HWOGDJFQGSO  B005HG9ESG       192623861
# 966446           US     51738595   RI9DOUO4L97ZD  B002RTC7AS       434738957
# 969221           US     51738595   R16AA6H0B5WT2  B00IDB0U3K       922427189
# 984576           US     47888198  R2ASYJQLJ33K2R  B00LMH07A8       241118077
# 1156287          US     43039286  R2FYUI1GTZ0BMD  B0019QG5CG       898440069
# ...

# %%
# data without NaN entries
len(main_data)-len(main_data.dropna())
# Out:
# 76

# %%
# 76 rows have entries that are NaN, this is only under either
# review_body or review_headline, I would assume this is because 
# the reviewer has not filled in these sections when writing the
# review.
#main_data.loc[main_data.isnull().any(axis=1)]
main_data.isna().any()
# Out:
# marketplace          False
# customer_id          False
# review_id            False
# product_id           False
# product_parent       False
# product_title        False
# product_category     False
# star_rating          False
# helpful_votes        False
# total_votes          False
# vine                 False
# verified_purchase    False
# review_headline       True
# review_body           True
# review_date          False
# dtype: bool

# %%
main_data = main_data.dropna()
